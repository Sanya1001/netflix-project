# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date

# %%
# Read in viewing history

viewing_history = pd.read_csv("NetflixViewingHistory.csv")
viewing_history
# Out:
#                                                  Title      Date
# 0            Marvel's Daredevil: Season 3: Revelations   2/28/22
# 1    Marvel's Daredevil: Season 3: Upstairs/Downstairs   2/28/22
# 2              Marvel's Daredevil: Season 3: Aftermath   2/24/22
# 3     Marvel's Daredevil: Season 3: The Devil You Know   2/24/22
# 4       Marvel's Daredevil: Season 3: The Perfect Game   2/21/22
# ..                                                 ...       ...
# 160                                 The Social Dilemma  10/26/20
# 161                     The West Wing: Season 1: Pilot  10/26/20
# 162              The Universe: Season 2: Alien Planets  10/26/20
# 163   Jeopardy!: Seth Wilson Collection: Episode #7361   4/22/20
# 164                   Tiger King: Not Your Average Joe   4/22/20
#
# [165 rows x 2 columns]

# %%
# Create list of titles where each titles is a list of strings 

split_titles_list = []

for i in range(len(viewing_history)):
    split_title = viewing_history.iloc[i,0].split()
    split_titles_list.append(split_title)
    
split_titles_list
# Out:
# [["Marvel's", 'Daredevil:', 'Season', '3:', 'Revelations'],
#  ["Marvel's", 'Daredevil:', 'Season', '3:', 'Upstairs/Downstairs'],
#  ["Marvel's", 'Daredevil:', 'Season', '3:', 'Aftermath'],
#  ["Marvel's", 'Daredevil:', 'Season', '3:', 'The', 'Devil', 'You', 'Know'],
#  ["Marvel's", 'Daredevil:', 'Season', '3:', 'The', 'Perfect', 'Game'],
#  ["Marvel's", 'Daredevil:', 'Season', '3:', 'Blindsided'],
#  ["Marvel's", 'Daredevil:', 'Season', '3:', 'No', 'Good', 'Deed'],
#  ["Marvel's", 'Daredevil:', 'Season', '3:', 'Please'],
#  ["Marvel's", 'Daredevil:', 'Season', '3:', 'Resurrection'],
#  ["Marvel's", 'The', 'Defenders:', 'Limited', 'Series:', 'The', 'Defenders'],
#  ["Marvel's",
#   'The',
#   'Defenders:',
#   'Limited',
#   'Series:',
#   'Fish',
#   'in',
#   'the',
#   'Jailhouse'],
#  ["Marvel's", 'The', 'Defenders:', 'Limited', 'Series:', 'Ashes,', 'Ashes'],
#  ["Marvel's", 'The', 'Defenders:', 'Limited', 'Series:', 'Take', 'Shelter'],
#  ["Marvel's", 'The', 'Defenders:', 'Limited', 'Series:', 'Royal', 'Dragon'],
#  ["Marvel's", 'The', 'Defenders:', 'Limited', 'Series:', 'Worst', 'Behavior'],
#  ["Marvel's",
#   'The',
#   'Defenders:',
#   'Limited',
#   'Series:',
#   'Mean',
#   'Right',
#   'Hook'],
#  ["Marvel's", 'The', 'Defenders:', 'Limited', 'Series:', 'The', 'H', 'Word'],
#  ["Marvel's",
#   'Daredevil:',
#   'Season',
#   '2:',
#   'A',
#   'Cold',
#   'Day',
#   'in',
#   "Hell's",
#   'Kitchen'],
#  ["Marvel's",
#   'Daredevil:',
#   'Season',
#   '2:',
#   'The',
#   'Dark',
#   'at',
#   'the',
#   'End',
#   'of',
#   'the',
#   'Tunnel'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', '.380'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'The', 'Man', 'in', 'the', 'Box'],
#  ["Marvel's",
#   'Daredevil:',
#   'Season',
#   '2:',
#   'Seven',
#   'Minutes',
#   'in',
#   'Heaven'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'Guilty', 'as', 'Sin'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'Semper', 'Fidelis'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'Regrets', 'Only'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'Kinbaku'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'Penny', 'and', 'Dime'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'New', "York's", 'Finest'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'Dogs', 'to', 'a', 'Gunfight'],
#  ["Marvel's", 'Daredevil:', 'Season', '2:', 'Bang'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Daredevil'],
#  ["Marvel's",
#   'Daredevil:',
#   'Season',
#   '1:',
#   'The',
#   'Ones',
#   'We',
#   'Leave',
#   'Behind'],
#  ["Marvel's",
#   'Daredevil:',
#   'Season',
#   '1:',
#   'The',
#   'Path',
#   'of',
#   'the',
#   'Righteous'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Nelson', 'v.', 'Murdock'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Speak', 'of', 'the', 'Devil'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Shadows', 'in', 'the', 'Glass'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Stick'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Condemned'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'World', 'on', 'Fire'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'In', 'the', 'Blood'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '7:',
#   'Descent:',
#   'Part',
#   '2'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Descent:',
#   'Part',
#   '1'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Rabbit', 'in', 'a', 'Snowstorm'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'Timescape'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Second',
#   'Chances'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Cut', 'Man'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Rightful',
#   'Heir'],
#  ["Marvel's", 'Daredevil:', 'Season', '1:', 'Into', 'the', 'Ring'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'Suspicions'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Frame',
#   'of',
#   'Mind'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'The',
#   'Chase'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'Lessons'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Starship',
#   'Mine'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Birthright:',
#   'Part',
#   '2'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Birthright:',
#   'Part',
#   '1'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'Tapestry'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Face',
#   'of',
#   'the',
#   'Enemy'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'Aquiel'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Ship',
#   'in',
#   'a',
#   'Bottle'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Chain',
#   'of',
#   'Command:',
#   'Part',
#   '2'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Chain',
#   'of',
#   'Command:',
#   'Part',
#   '1'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'The',
#   'Quality',
#   'of',
#   'Life'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'A',
#   'Fistful',
#   'of',
#   'Datas'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'Rascals'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Best',
#   'of',
#   'Both',
#   'Worlds:',
#   'Part',
#   '1'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'The',
#   'Wounded'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   "Data's",
#   'Day'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '5:', 'Darmok'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'Who',
#   'Watches',
#   'the',
#   'Watchers'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '2:',
#   'The',
#   'Measure',
#   'of',
#   'a',
#   'Man'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'True', 'Q'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'Schisms'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '6:', 'Relics'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Man',
#   'of',
#   'the',
#   'People'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   'Realm',
#   'of',
#   'Fear'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '6:',
#   "Time's",
#   'Arrow:',
#   'Part',
#   '2'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   "Time's",
#   'Arrow:',
#   'Part',
#   '1'],
#  ['Star',
#   'Trek:',
#   'Deep',
#   'Space',
#   'Nine:',
#   'Season',
#   '1:',
#   'Emissary:',
#   'Parts',
#   '1',
#   '&',
#   '2'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'The',
#   'Inner',
#   'Light'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'The',
#   'Next',
#   'Phase'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '5:', 'I,', 'Borg'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Imaginary',
#   'Friend'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'The',
#   'Perfect',
#   'Mate'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Cost',
#   'of',
#   'Living'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'The',
#   'First',
#   'Duty'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Cause',
#   'and',
#   'Effect'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'The',
#   'Outcast'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '5:', 'Ethics'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Power',
#   'Play'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '5:', 'Conundrum'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'The',
#   'Masterpiece',
#   'Society'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '5:', 'Violations'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Hero',
#   'Worship'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'New',
#   'Ground'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'A',
#   'Matter',
#   'of',
#   'Time'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Unification:',
#   'Part',
#   '2'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Unification:',
#   'Part',
#   '1'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'The',
#   'Game'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '5:', 'Disaster'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Silicon',
#   'Avatar'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Ensign',
#   'Ro'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '5:',
#   'Redemption:',
#   'Part',
#   '2'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'Redemption:',
#   'Part',
#   '1'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'In',
#   'Theory'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'The',
#   'Drumhead'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'The',
#   "Mind's",
#   'Eye'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'The',
#   'Host'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'Half',
#   'A',
#   'Life'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '4:', 'Qpid'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'The',
#   'Nth',
#   'Degree'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'Identity',
#   'Crisis'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'Night',
#   'Terrors'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   "Galaxy's",
#   'Child'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'First',
#   'Contact'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '4:', 'Clues'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   "Devil's",
#   'Due'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'The',
#   'Loss'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'Final',
#   'Mission'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'Future',
#   'Imperfect'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '4:', 'Reunion'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '4:', 'Legacy'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'Remember',
#   'Me'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'Suddenly',
#   'Human'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '4:', 'Brothers'],
#  ['For', 'the', 'Love', 'of', 'Spock'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '4:', 'Family'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '4:',
#   'The',
#   'Best',
#   'of',
#   'Both',
#   'Worlds:',
#   'Part',
#   '2'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'Transfigurations'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'Menage',
#   'a',
#   'Troi'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '3:', 'Sarek'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Most',
#   'Toys'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'Hollow',
#   'Pursuits'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '3:', 'Tin', 'Man'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   "Captain's",
#   'Holiday'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '3:', 'Allegiance'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'Sins',
#   'of',
#   'the',
#   'Father'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Offspring'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   "Yesterday's",
#   'Enterprise'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'A',
#   'Matter',
#   'of',
#   'Perspective'],
#  ['Star', 'Trek:', 'The', 'Next', 'Generation:', 'Season', '3:', 'Deja', 'Q'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'High',
#   'Ground'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Hunted'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Defector'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Vengeance',
#   'Factor'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Price'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Enemy'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'Booby',
#   'Trap'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Bonding'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '3:',
#   'The',
#   'Survivors'],
#  ['Star',
#   'Trek:',
#   'The',
#   'Next',
#   'Generation:',
#   'Season',
#   '1:',
#   'Encounter',
#   'at',
#   'Farpoint:',
#   'Parts',
#   '1',
#   '&',
#   '2'],
#  ['Star',
#   'Trek:',
#   'Voyager:',
#   'Season',
#   '1:',
#   'Caretaker:',
#   'Parts',
#   '1',
#   '&',
#   '2'],
#  ['Get', 'Me', 'Roger', 'Stone'],
#  ['Star', 'Trek:', 'Season', '1:', 'Pilot:', 'The', 'Cage'],
#  ['The', "Queen's", 'Gambit:', 'Limited', 'Series:', 'End', 'Game'],
#  ['The', "Queen's", 'Gambit:', 'Limited', 'Series:', 'Adjournment'],
#  ['The', "Queen's", 'Gambit:', 'Limited', 'Series:', 'Fork'],
#  ['The', "Queen's", 'Gambit:', 'Limited', 'Series:', 'Middle', 'Game'],
#  ['The', "Queen's", 'Gambit:', 'Limited', 'Series:', 'Doubled', 'Pawns'],
#  ['The', "Queen's", 'Gambit:', 'Limited', 'Series:', 'Exchanges'],
#  ['The', "Queen's", 'Gambit:', 'Limited', 'Series:', 'Openings'],
#  ['The', 'Social', 'Dilemma'],
#  ['The', 'West', 'Wing:', 'Season', '1:', 'Pilot'],
#  ['The', 'Universe:', 'Season', '2:', 'Alien', 'Planets'],
#  ['Jeopardy!:', 'Seth', 'Wilson', 'Collection:', 'Episode', '#7361'],
#  ['Tiger', 'King:', 'Not', 'Your', 'Average', 'Joe']]

# %%
# Create variable with number of shows/movies watched; used for indexing later

items_watched = len(split_titles_list)
items_watched
# Out:
# 165

# %%
# Create list of shortened titles (removes season numbers and episode names from series)

short_titles_list = []
for i in range(items_watched):
    current_item = split_titles_list[i]
    words = len(current_item)
    j = 0
    while j < words:
        if ":" in current_item[j]:
            current_item[j] = current_item[j].replace(":", "")
            short_titles_list.append(current_item[0:j+1])
            j = words
            # If there is a colon, take only the words before the colon
        else:
            j += 1
            # Move to next word
        if (j == words-1) == True:
            short_titles_list.append(current_item[0:j+1])
            j = words
            # If there is no colon by the end of the word, take the whole title (it's a movie and doesn't need shortening)
        
short_titles_list
# Out:
# [["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'The', 'Defenders'],
#  ["Marvel's", 'The', 'Defenders'],
#  ["Marvel's", 'The', 'Defenders'],
#  ["Marvel's", 'The', 'Defenders'],
#  ["Marvel's", 'The', 'Defenders'],
#  ["Marvel's", 'The', 'Defenders'],
#  ["Marvel's", 'The', 'Defenders'],
#  ["Marvel's", 'The', 'Defenders'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ["Marvel's", 'Daredevil'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ["Marvel's", 'Daredevil'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ["Marvel's", 'Daredevil'],
#  ['Star', 'Trek'],
#  ["Marvel's", 'Daredevil'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['For', 'the', 'Love', 'of', 'Spock'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Star', 'Trek'],
#  ['Get', 'Me', 'Roger', 'Stone'],
#  ['Star', 'Trek'],
#  ['The', "Queen's", 'Gambit'],
#  ['The', "Queen's", 'Gambit'],
#  ['The', "Queen's", 'Gambit'],
#  ['The', "Queen's", 'Gambit'],
#  ['The', "Queen's", 'Gambit'],
#  ['The', "Queen's", 'Gambit'],
#  ['The', "Queen's", 'Gambit'],
#  ['The', 'Social', 'Dilemma'],
#  ['The', 'West', 'Wing'],
#  ['The', 'Universe'],
#  ['Jeopardy!'],
#  ['Tiger', 'King']]

# %%
# Making sure the correct number of entries made it through

print(len(short_titles_list))
# Out:
# 165

# %%
# Create list of unique titles (i.e. only one entry per series) and list of episodes of each series watched (movies will
# only have one)
# Number of episodes watched per series could be used to create a bias so we are more likely to reccomend items similar to
# shows the viewer watched many episodes of instead of treating them equally to a single episode
# Dummy check to make sure lengths match
# We could combine these into a dictionary or 2D array if it makes life easier

unique_titles = []
for i in range(items_watched):
    if short_titles_list[i] not in unique_titles:
        unique_titles.append(short_titles_list[i])

number_episodes = []
for title in unique_titles:
    title_count = 0
    for title_2 in short_titles_list:
        if title == title_2:
            title_count += 1
    number_episodes.append(title_count)

print(unique_titles)
print("Length:", len(unique_titles))
print(number_episodes)
print("Length:", len(number_episodes))
# Out:
# [["Marvel's", 'Daredevil'], ["Marvel's", 'The', 'Defenders'], ['Star', 'Trek'], ['For', 'the', 'Love', 'of', 'Spock'], ['Get', 'Me', 'Roger', 'Stone'], ['The', "Queen's", 'Gambit'], ['The', 'Social', 'Dilemma'], ['The', 'West', 'Wing'], ['The', 'Universe'], ['Jeopardy!'], ['Tiger', 'King']]
# Length: 11
# [35, 8, 108, 1, 1, 7, 1, 1, 1, 1, 1]
# Length: 11

# %%
# Calculate days since viewing each item; we have the information and might as well make a recency bias.  For example, the
# first viewing in my history is the piolt episode of Tiger King, which I watched once a long time ago and haven't since
# watched anything like it.  It should not have the same weight on my reccomendations as what I was watching 2 months ago.

view_dates = []
for i in range(len(viewing_history)):
    view_date_list = viewing_history.iloc[i,1].split("/")
    view_dates.append(view_date_list)

days_since_viewing = []
today = date.today()
for j in range(len(view_dates)):
    view_date = date(int(view_dates[j][2])+2000, int(view_dates[j][0]), int(view_dates[j][1]))
    delta = today - view_date
    days_since_viewing.append(delta.days)

print(days_since_viewing)
# Out:
# [38, 38, 42, 42, 45, 50, 52, 55, 57, 58, 59, 61, 61, 61, 61, 66, 66, 67, 67, 68, 69, 70, 70, 70, 73, 76, 76, 76, 78, 79, 93, 93, 93, 95, 95, 95, 95, 98, 99, 100, 104, 104, 104, 105, 112, 112, 113, 113, 114, 115, 119, 136, 138, 140, 140, 145, 146, 148, 149, 153, 153, 153, 155, 157, 163, 164, 164, 165, 166, 167, 168, 169, 173, 176, 177, 180, 183, 183, 185, 186, 189, 189, 190, 192, 195, 198, 199, 201, 204, 206, 207, 212, 215, 220, 224, 225, 225, 226, 227, 228, 231, 232, 233, 234, 234, 235, 236, 236, 238, 241, 241, 243, 244, 245, 247, 248, 250, 252, 253, 253, 255, 256, 258, 258, 259, 259, 262, 262, 262, 263, 264, 266, 268, 270, 273, 274, 275, 276, 277, 277, 279, 280, 280, 283, 283, 283, 285, 286, 289, 289, 375, 380, 381, 517, 520, 523, 524, 524, 524, 525, 528, 528, 528, 715, 715]

# %%
average_days_since_viewing = []
for title in unique_titles:
    duplicate_title_index_list = []
    for i in range(items_watched):
        if short_titles_list[i] == title:
            duplicate_title_index_list.append(i)
    days_since_viewing_all_duplicates = []
    for j in range(len(duplicate_title_index_list)):
        days_since_viewing_all_duplicates.append(days_since_viewing[duplicate_title_index_list[j]])
    avg = np.mean(days_since_viewing_all_duplicates)
    average_days_since_viewing.append(avg)

print(len(average_days_since_viewing))
average_days_since_viewing
# Out:
# 11
# [75.51428571428572,
#  61.625,
#  214.94444444444446,
#  259.0,
#  380.0,
#  522.4285714285714,
#  528.0,
#  528.0,
#  528.0,
#  715.0,
#  715.0]
